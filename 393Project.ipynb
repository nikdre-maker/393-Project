# %%
#Identify which URL is phishing or normal, binary classifier
import pandas as pd
from scipy.io import arff
#import data since it's a arff file have to convert it to a dataframe

data = arff.loadarff("/content/Training Dataset.arff")
df = pd.DataFrame(data)

#checking for bytes objects and turning them into strings so code works, iterate through each column and value
for column in df.columns:
  fixed = []
  for value in df[column]:
    # if bytes then fix
    if type(value) == bytes:
      fixed.append(value.decode())
    else:
      fixed.append(value)
  df[column] = fixed

#drop missing values
df = df.dropna()

df


#normalize features


#feature selection




#Logistic Regression Model




#Sequential Neural Network
# Out:
#                                                0      \
# 0  [b'-1', b'1', b'1', b'1', b'-1', b'-1', b'-1',...
#
#                                                1      \
# 0  [b'1', b'1', b'1', b'1', b'1', b'-1', b'0', b'...
#
#                                                2      \
# 0  [b'1', b'0', b'1', b'1', b'1', b'-1', b'-1', b...
#
#                                                3      \
# 0  [b'1', b'0', b'1', b'1', b'1', b'-1', b'-1', b...
#
#                                                4      \
# 0  [b'1', b'0', b'-1', b'1', b'1', b'-1', b'1', b...
#
#                                                5      \
# 0  [b'-1', b'0', b'-1', b'1', b'-1', b'-1', b'1',...
#
#                                                6      \
# 0  [b'1', b'0', b'-1', b'1', b'1', b'-1', b'-1', ...
#
#                                                7      \
# 0  [b'1', b'0', b'1', b'1', b'1', b'-1', b'-1', b...
#
#                                                8      \
# 0  [b'1', b'0', b'-1', b'1', b'1', b'-1', b'1', b...
#
#                                                9      ...  \
# 0  [b'1', b'1', b'-1', b'1', b'1', b'-1', b'-1', ...  ...
#
#                                                11045  \
# 0  [b'1', b'-1', b'1', b'1', b'1', b'-1', b'1', b...
#
#                                                11046  \
# 0  [b'-1', b'-1', b'1', b'1', b'1', b'-1', b'1', ...
#
#                                                11047  \
# 0  [b'-1', b'-1', b'1', b'1', b'1', b'-1', b'1', ...
#
#                                                11048  \
# 0  [b'1', b'-1', b'1', b'1', b'1', b'-1', b'-1', ...
#
#                                                11049  \
# 0  [b'-1', b'-1', b'1', b'1', b'-1', b'-1', b'1',...
#
#                                                11050  \
# 0  [b'1', b'-1', b'1', b'-1', b'1', b'1', b'1', b...
#
#                                                11051  \
# 0  [b'-1', b'1', b'1', b'-1', b'-1', b'-1', b'1',...
#
#                                                11052  \
# 0  [b'1', b'-1', b'1', b'1', b'1', b'-1', b'1', b...
#
#                                                11053  \
# 0  [b'-1', b'-1', b'1', b'1', b'1', b'-1', b'-1',...
#
#                                                11054
# 0  [b'-1', b'-1', b'1', b'1', b'1', b'-1', b'-1',...
#
# [1 rows x 11055 columns]
